# %%
import pandas as pd

# %%
citydf = pd.read_csv('Resources/cities.csv')

citydf.to_html('data.html', index=False)

table = citydf.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temperature</th>
#       <th>Humidity</th>
#       <th>Cloud Coverage</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kapaa</td>
#       <td>22.0752</td>
#       <td>-159.3190</td>
#       <td>84.11</td>
#       <td>70</td>
#       <td>89</td>
#       <td>5.99</td>
#       <td>US</td>
#       <td>1665435244</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>São João da Barra</td>
#       <td>-21.6403</td>
#       <td>-41.0511</td>
#       <td>80.69</td>
#       <td>84</td>
#       <td>9</td>
#       <td>7.40</td>
#       <td>BR</td>
#       <td>1665435244</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dingle</td>
#       <td>10.9995</td>
# ...
